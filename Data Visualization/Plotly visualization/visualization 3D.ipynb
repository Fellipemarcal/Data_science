# %%
import plotly.graph_objects as go
import plotly.express as px
import numpy as np
import pandas as pd
import plotly.io as pio
pio.renderers.default = "notebook" # ouvre le graphique dans le notebook, si nous remplaçons 'notebook' par "browser" le graphique s'ouvrira dans une nouvelle ongle
fig = px.line(x=[1, 2], y=[3, 4])

print(fig)
# Out:
# Figure({
#     'data': [{'hovertemplate': 'x=%{x}<br>y=%{y}<extra></extra>',
#               'legendgroup': '',
#               'line': {'color': '#636efa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines',
#               'name': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'scatter',
#               'x': {'bdata': 'AQI=', 'dtype': 'i1'},
#               'xaxis': 'x',
#               'y': {'bdata': 'AwQ=', 'dtype': 'i1'},
#               'yaxis': 'y'}],
#     'layout': {'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'x'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'y'}}}
# })

# %%
'''3D Diagramme de dispersion
Le diagramme de scatter 3D montre les points de données en trois dimensions, ajoutant des informations supplémentaires en ajustant la couleur, la taille et le style des points.
Ces ajustements aident à rendre l’intrigue plus claire et plus facile à comprendre.
Vous pouvez créer un nuage de points 3D en utilisant la fonction de la classe plotly.express.scatter_3d'''
df = px.data.tips()

fig = px.scatter_3d(df, x="total_bill", y="sex", z="tip")

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="678186f4-f1f9-484d-bd68-071ba9d73c1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("678186f4-f1f9-484d-bd68-071ba9d73c1e")) {                    Plotly.newPlot(                        "678186f4-f1f9-484d-bd68-071ba9d73c1e",                        [{"hovertemplate":"total_bill=%{x}\u003cbr\u003esex=%{y}\u003cbr\u003etip=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":
# ...

# %%
'''Personnalisation du nuage de points 3D.

Exemple : Nous utiliserons la personnalisation suivante -

-> couleur : Définissez la couleur des marqueurs
-> taille : Définir la taille du marqueur
-> symbole : Définir le symbole de l’intrigue'''
df = px.data.tips()

fig = px.scatter_3d(df, x="total_bill", y="sex", z="tip", color='day', 
                    size='total_bill', symbol='time')

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="11f2b6b8-db74-434f-8a76-c56804e1e4c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("11f2b6b8-db74-434f-8a76-c56804e1e4c1")) {                    Plotly.newPlot(                        "11f2b6b8-db74-434f-8a76-c56804e1e4c1",                        [{"hovertemplate":"day=Sun\u003cbr\u003etime=Dinner\u003cbr\u003etotal_bill=%{marker.size}\u003cbr\u003esex=%{y}\u003cbr\u003etip=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sun, Dinner","marker":{"color":"#636efa","size":{"dtype":"f
# ...
