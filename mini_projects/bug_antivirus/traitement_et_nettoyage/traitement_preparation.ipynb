# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('bug_dataset_50k.csv')

# %%
df.columns
# Out:
# Index(['bug_id', 'title', 'description', 'error_code', 'bug_category',
#        'bug_domain', 'tech_stack', 'severity', 'environment', 'developer_role',
#        'root_cause', 'suggested_fix', 'explanation', 'created_at'],
#       dtype='str')

# %%
df['created_at'] = pd.to_datetime(df['created_at'], errors = 'coerce')
df['mois'] = df['created_at'].dt.to_period('M')
df['error_code'] = (
    df.groupby(['severity', 'bug_category', 'tech_stack'])['error_code']
    .transform(lambda x: x.fillna(x.mode().iloc[0] if not x.mode().empty else x))
)

# %%
df['mois'].unique()
# Out:
# <PeriodArray>
# ['2025-04', '2025-07', '2025-05', '2025-09', '2025-08', '2025-06', '2026-01',
#  '2025-12', '2025-10', '2025-03', '2025-11', '2025-02', '2026-02']
# Length: 13, dtype: period[M]

# %%
# je crois qu'il soit plus interessant qu'on crée une variable pour chaque 3 mois
fv_ap_25 = df[df['mois'].astype(str).isin(['2025-02','2025-03','2025-04'])]
ma_jl_25 = df[df['mois'].astype(str).isin(['2025-05','2025-06','2025-07'])]
ag_ou_25 = df[df['mois'].astype(str).isin(['2025-08','2025-09','2025-10'])]
nv_jn_26 = df[df['mois'].astype(str).isin(['2025-11','2025-12','2026-01'])]

# %%
fv_ap_25.columns
# Out:
# Index(['bug_id', 'title', 'description', 'error_code', 'bug_category',
#        'bug_domain', 'tech_stack', 'severity', 'environment', 'developer_role',
#        'root_cause', 'suggested_fix', 'explanation', 'created_at', 'mois'],
#       dtype='str')

# %%
fv_ap_25
# Out:
#            bug_id                                      title  \
# 0      BUG_000001                 API Bug detected in system
# 16     BUG_000017             Memory Leak detected in system
# 23     BUG_000024          Deployment Bug detected in system
# 39     BUG_000040    Frontend Routing Bug detected in system
# 42     BUG_000043         Concurrency Bug detected in system
# ...           ...                                        ...
# 49984  BUG_049985         Performance Bug detected in system
# 49985  BUG_049986      Authentication Bug detected in system
# 49988  BUG_049989       Backend Logic Bug detected in system
# 49989  BUG_049990  Security Vulnerability detected in system
# 49990  BUG_049991         Concurrency Bug detected in system
#
#                                              description  error_code  \
# 0      This issue relates to a api bug occurring in t...       403.0
# 16     This issue relates to a memory leak occurring ...       404.0
# 23     This issue relates to a deployment bug occurri...       400.0
# 39     This issue relates to a frontend routing bug o...       502.0
# 42     This issue relates to a concurrency bug occurr...       401.0
# ...                                                  ...         ...
# 49984  This issue relates to a performance bug occurr...       400.0
# 49985  This issue relates to a authentication bug occ...       403.0
# 49988  This issue relates to a backend logic bug occu...       403.0
# 49989  This issue relates to a security vulnerability...       400.0
# 49990  This issue relates to a concurrency bug occurr...       404.0
#
#                  bug_category       bug_domain   tech_stack  severity  \
# 0                     API Bug           Mobile  Spring Boot      High
# 16                Memory Leak             Data      Node.js  Critical
# 23             Deployment Bug  Web Development          GCP  Critical
# 39       Frontend Routing Bug             Data      Angular  Critical
# 42            Concurrency Bug  Backend Systems          AWS    Medium
# ...                       ...              ...          ...       ...
# 49984         Performance Bug           DevOps      Node.js      High
# 49985      Authentication Bug  Backend Systems   PostgreSQL       Low
# 49988       Backend Logic Bug             Data   PostgreSQL  Critical
# 49989  Security Vulnerability             Data        React      High
# 49990         Concurrency Bug             Data  Spring Boot       Low
#
#        environment        developer_role  \
# 0      Development  Full-Stack Developer
# 16     Development      Mobile Developer
# 23     Development           QA Engineer
# 39     Development    Frontend Developer
# 42     Development         Data Engineer
# ...            ...                   ...
# 49984  Development      Mobile Developer
# 49985   Production      Mobile Developer
# 49988  Development           QA Engineer
# 49989      Staging  Full-Stack Developer
# 49990      Staging           QA Engineer
#
#                                               root_cause  \
# 0      Misconfiguration or logic issue related to api...
# 16     Misconfiguration or logic issue related to mem...
# 23     Misconfiguration or logic issue related to dep...
# 39     Misconfiguration or logic issue related to fro...
# 42     Misconfiguration or logic issue related to con...
# ...                                                  ...
# 49984  Misconfiguration or logic issue related to per...
# 49985  Misconfiguration or logic issue related to aut...
# 49988  Misconfiguration or logic issue related to bac...
# 49989  Misconfiguration or logic issue related to sec...
# 49990  Misconfiguration or logic issue related to con...
#
#                                            suggested_fix  \
# 0      Review and fix the api bug according to best p...
# 16     Review and fix the memory leak according to be...
# 23     Review and fix the deployment bug according to...
# 39     Review and fix the frontend routing bug accord...
# 42     Review and fix the concurrency bug according t...
# ...                                                  ...
# 49984  Review and fix the performance bug according t...
# 49985  Review and fix the authentication bug accordin...
# 49988  Review and fix the backend logic bug according...
# 49989  Review and fix the security vulnerability acco...
# 49990  Review and fix the concurrency bug according t...
#
#                                              explanation created_at     mois
# 0      This bug requires a full-stack developer due t... 2025-04-07  2025-04
# 16     This bug requires a mobile developer due to it... 2025-03-12  2025-03
# 23     This bug requires a qa engineer due to its nat... 2025-03-11  2025-03
# 39     This bug requires a frontend developer due to ... 2025-03-14  2025-03
# 42     This bug requires a data engineer due to its n... 2025-02-27  2025-02
# ...                                                  ...        ...      ...
# 49984  This bug requires a mobile developer due to it... 2025-03-17  2025-03
# 49985  This bug requires a mobile developer due to it... 2025-04-19  2025-04
# 49988  This bug requires a qa engineer due to its nat... 2025-04-26  2025-04
# 49989  This bug requires a full-stack developer due t... 2025-04-08  2025-04
# 49990  This bug requires a qa engineer due to its nat... 2025-03-29  2025-03
#
# [12005 rows x 15 columns]
