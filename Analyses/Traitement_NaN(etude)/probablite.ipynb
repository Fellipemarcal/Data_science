# %%
import random

# %%
ind = 5
grp = ['Fellipe','Maria','Ana','Pedro','joao']
fml = [('garçon','fille'),('fille','fille'),('fille','garçon'),('garçon','garçon')]#chaque personne a une probabalité de 1/5 d'être affichée
a = 0
b = len(fml)
for i in range(ind):
    c = random.randint(a,b - 1)
    print(fml[c])
# Out:
# ('garçon', 'garçon')
# ('garçon', 'garçon')
# ('garçon', 'fille')
# ('garçon', 'fille')
# ('fille', 'fille')
