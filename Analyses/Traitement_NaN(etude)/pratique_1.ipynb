# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv')

# %%
df.isnull().head(20) # cette commande nous retourne lignes qui contiennent des valeurs NaN et la position de ces valeurs 
#dans le dataframe
# Out:
#        id   date  first_name  last_name  email  gender  ip_address  country  \
# 0   False  False       False      False  False   False       False    False
# 1   False  False       False      False  False   False       False    False
# 2   False  False       False      False  False   False       False    False
# 3   False  False       False      False  False   False       False    False
# 4   False  False       False      False  False   False       False    False
# 5   False  False       False      False  False   False       False    False
# 6   False  False       False      False  False   False       False    False
# 7   False  False       False      False  False   False       False    False
# 8   False  False       False      False  False   False       False    False
# 9   False  False       False      False  False   False       False    False
# 10  False  False       False      False  False   False       False    False
# ...

# %%
df.notnull().head(20) # cette commande nous retourne lignes qui contiennent des valeurs NaN e la position de ces valeurs 
#dans le dataframe (c'est la meme chose de la commande précédente, la différence ici c'est que les valeurs NaN sont répresentés
#par 'false')
# Out:
#       id  date  first_name  last_name  email  gender  ip_address  country  \
# 0   True  True        True       True   True    True        True     True
# 1   True  True        True       True   True    True        True     True
# 2   True  True        True       True   True    True        True     True
# 3   True  True        True       True   True    True        True     True
# 4   True  True        True       True   True    True        True     True
# 5   True  True        True       True   True    True        True     True
# 6   True  True        True       True   True    True        True     True
# 7   True  True        True       True   True    True        True     True
# 8   True  True        True       True   True    True        True     True
# 9   True  True        True       True   True    True        True     True
# 10  True  True        True       True   True    True        True     True
# 11  True  True        True       True   True    True        True     True
# ...

# %%
df.dropna().head(20) # ça nous retourne les vingt premières lignes qui n'continnent aucun NaN, avec 'dropna' on enleve les lignes qui en continnent
# Out:
#     id        date first_name   last_name                       email  gender  \
# 2    3  03/17/2021        Erl  Kilminster       ekilminster2@etsy.com    Male
# 3    4  03/19/2021      Grata      Brantl            gbrantl3@umn.edu  Female
# 4    5  03/24/2021      Kanya     Beasant         kbeasant4@jigsy.com    Male
# 7    8  03/08/2021       Codi     Feasley            cfeasley7@ed.gov    Male
# 8    9  03/09/2021     Waylon    Heersema       wheersema8@tumblr.com    Male
# 11  12  03/16/2021     Bailie       Wyman            bwymanb@lulu.com    Male
# 12  13  03/05/2021     Janice    Morillas  jmorillasc@miibeian.gov.cn  Female
# 14  15  03/21/2021     Oralie      Maryon             omaryone@va.gov  Female
# 15  16  03/24/2021     Julina       Faint        jfaintf@amazon.co.jp  Female
# 16  17  03/27/2021        Eve     Allaway        eallawayg@ebay.co.uk  Female
# 18  19  03/16/2021      Judye       Behan           jbehani@google.es  Female
# ...

# %%
df[df['tax'].isnull()] # cette commande nous retourne tous les lignes où la colunnu 'tax' contiennent un valeur manquante
# Out:
#       id        date first_name   last_name                   email  gender  \
# 0      1  03/28/2021    Marylin      Alders    malders0@shop-pro.jp    Male
# 1      2  03/19/2021      Hinda    Harridge      hharridge1@gnu.org  Female
# 5      6  03/25/2021      Titos  Braybrooke    tbraybrooke5@umn.edu  Female
# 6      7  03/14/2021        Ava     Kencott      akencott6@phoca.cz  Female
# 9     10  03/23/2021  Guglielma      Gookes   ggookes9@amazon.co.uk    Male
# ..   ...         ...        ...         ...                     ...     ...
# 985  986  03/29/2021     Yvonne  Longworthy   ylongworthyrd@163.com  Female
# 992  993  03/04/2021    Maurene  Guilloneau  mguilloneaurk@about.me    Male
# 993  994  03/22/2021      Ossie      Snelle        osnellerl@nhs.uk    Male
# 995  996  03/24/2021       Duff      Errigo    derrigorn@elpais.com  Female
# 998  999  03/17/2021    Paquito       Tesoe  ptesoerq@rakuten.co.jp    Male
#
#          ip_address        country price_paid  tax
# ...

# %%
df_tax_m = df[df['tax'].isnull()] # nous stockerons le résultat de commande précédent dans cette variable pour nous puissions
#continuer notre filtrage

# %%
df_tax_m[df_tax_m['country'].isnull()] # ici nous faisons une nouvelle filtrage sur la filtrage que nous venons de faire
#(cella sur la colunne 'tax') -> ici notre filtrage se concentre sur la colunne 'country' et nous filtrons ici aussi les
#les valeurs manquants
# Out:
#       id        date first_name     last_name  \
# 131  132  03/09/2021      Ricky        Guerra
# 210  211  03/03/2021  Merrielle        Jarret
# 258  259  03/03/2021       Dasi       Babbage
# 271  272  03/19/2021      Titos       Copelli
# 283  284  03/23/2021    Ingemar         Kropp
# 288  289  03/27/2021      Homer        Testin
# 358  359  03/01/2021       Etan        Muller
# 466  467  03/05/2021     Virgie          Face
# 587  588  03/23/2021     Xavier      Sleeford
# 590  591  03/29/2021    Bertram        Hazael
# 653  654  03/28/2021       Reid       Yushkin
# 774  775  03/07/2021  Anastasia      Northing
# 837  838  03/02/2021     Lilith         Keave
# 844  845  03/30/2021        Dav  Wolstenholme
# 893  894  03/13/2021    Quintin     Kettleson
# 905  906  03/21/2021    Aloysia     Benninger
# 930  931  03/03/2021      Tessa      Janowicz
# 947  948  03/18/2021    Ardelia         Jaggs
#
#                                email  gender       ip_address country  \
# ...
