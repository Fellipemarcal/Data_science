# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('social_media_addiction.csv')
def cls_age(i):
    if i < 26.5:
        return 'Plus Jeune'
    else:
        return 'Adulte'
df['Classe_age'] = df['Age'].apply(cls_age)

# %%
p_jeune = df[df['Classe_age'] == 'Plus Jeune']
adulte = df[df['Classe_age'] == 'Adulte']

# %%
p_jeune.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, 0 to 19
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     11 non-null     int64
#  1   Age                         11 non-null     int64
#  2   Gender                      11 non-null     object
#  3   Platform                    11 non-null     object
#  4   Daily_Usage_Time_min        11 non-null     int64
#  5   Posts_Per_Day               11 non-null     int64
#  6   Likes_Received_Daily        11 non-null     int64
#  7   Comments_Received_Daily     11 non-null     int64
#  8   Messages_Sent_Daily         11 non-null     int64
#  9   Scroll_Rate_ppm             11 non-null     int64
#  10  Addiction_Level             11 non-null     object
#  11  Emotional_State_Post_Usage  11 non-null     object
#  12  Productivity_Loss_Score     11 non-null     int64
#  13  Mental_Health_Index         11 non-null     int64
#  14  FOMO_Score                  11 non-null     int64
#  15  Classe_age                  11 non-null     object
# dtypes: int64(11), object(5)
# memory usage: 1.5+ KB

# %%
#les niveaux d'addiction élevés (high/severe) sont associés à des états émotionnels plus négatifs ou plus intenses (comme anxious, depressed
#overwhelmed, stressed).
#On remarque aussi que ces cas sont plus fréquents chez les plus jeunes
add_lvl = (
    p_jeune
    .groupby(['Emotional_State_Post_Usage','Addiction_Level'])
    .size()
    .sort_values(ascending = False)
)
add_lvl
# Out:
# Emotional_State_Post_Usage  Addiction_Level
# Angry                       Moderate           1
# Anxious                     High               1
# Bored                       Severe             1
# Curious                     Moderate           1
# Depressed                   Severe             1
# Drained                     Severe             1
# Envious                     High               1
# Insecure                    High               1
# Lonely                      High               1
# Overwhelmed                 High               1
# Stressed                    High               1
# dtype: int64

# %%
p_jeune['Emotional_State_Post_Usage'].unique()
# Out:
# array(['Anxious', 'Depressed', 'Stressed', 'Bored', 'Envious', 'Lonely',
#        'Angry', 'Curious', 'Drained', 'Overwhelmed', 'Insecure'],
#       dtype=object)

# %%
adulte
# Out:
#     User_ID  Age  Gender   Platform  Daily_Usage_Time_min  Posts_Per_Day  \
# 2      1003   28  Female   LinkedIn                    45              0
# 3      1004   35    Male   Facebook                    90              2
# 6      1007   31  Female  Instagram                    60              1
# 8      1009   29  Female  Pinterest                    30              0
# 9      1010   40    Male   Facebook                    50              1
# 12     1013   33  Female   LinkedIn                    20              0
# 15     1016   27    Male  Instagram                   110              2
# 16     1017   38  Female   Facebook                    40              1
# 18     1019   30    Male    YouTube                   130              0
#
#     Likes_Received_Daily  Comments_Received_Daily  Messages_Sent_Daily  \
# 2                      5                        2                   15
# 3                     30                       10                   20
# 6                     50                        8                   30
# 8                      2                        0                    5
# 9                     15                        3                   10
# 12                     1                        0                    5
# 15                    75                       10                   25
# 16                    20                        5                   15
# 18                    15                        2                    0
#
#     Scroll_Rate_ppm Addiction_Level Emotional_State_Post_Usage  \
# 2                10             Low                  Motivated
# 3                25        Moderate                    Neutral
# 6                20        Moderate                      Happy
# 8                15             Low                   Inspired
# 9                10             Low                    Neutral
# 12                5             Low                    Neutral
# 15               35        Moderate                    Anxious
# 16               10             Low                  Connected
# 18               10        Moderate                    Relaxed
#
#     Productivity_Loss_Score  Mental_Health_Index  FOMO_Score Classe_age
# 2                         2                   80           3     Adulte
# 3                         4                   65           5     Adulte
# 6                         3                   75           4     Adulte
# 8                         1                   85           2     Adulte
# 9                         2                   70           3     Adulte
# 12                        1                   90           2     Adulte
# 15                        4                   60           6     Adulte
# 16                        2                   80           3     Adulte
# 18                        4                   70           4     Adulte

# %%
#ici nous faison la même analyse chez les adultes et nous pouvons remarquer qu'il y a une grand réduction des cas élevés
#avec des niveaux d'addictions plus baisses, nous pouvons abserver la presque absence des cas émotionels négatifs
add_lvl_ = (
    adulte
    .groupby(['Emotional_State_Post_Usage','Addiction_Level'])
    .size()
    .sort_values(ascending = False)
)
add_lvl_
# Out:
# Emotional_State_Post_Usage  Addiction_Level
# Neutral                     Low                2
# Anxious                     Moderate           1
# Happy                       Moderate           1
# Connected                   Low                1
# Inspired                    Low                1
# Motivated                   Low                1
# Neutral                     Moderate           1
# Relaxed                     Moderate           1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     20 non-null     int64
#  1   Age                         20 non-null     int64
#  2   Gender                      20 non-null     object
#  3   Platform                    20 non-null     object
#  4   Daily_Usage_Time_min        20 non-null     int64
#  5   Posts_Per_Day               20 non-null     int64
#  6   Likes_Received_Daily        20 non-null     int64
#  7   Comments_Received_Daily     20 non-null     int64
#  8   Messages_Sent_Daily         20 non-null     int64
#  9   Scroll_Rate_ppm             20 non-null     int64
#  10  Addiction_Level             20 non-null     object
#  11  Emotional_State_Post_Usage  20 non-null     object
#  12  Productivity_Loss_Score     20 non-null     int64
#  13  Mental_Health_Index         20 non-null     int64
#  14  FOMO_Score                  20 non-null     int64
#  15  Classe_age                  20 non-null     object
# dtypes: int64(11), object(5)
# memory usage: 2.6+ KB

# %%
df['Interactions'] = df['Posts_Per_Day'] + df['Likes_Received_Daily'] + df['Comments_Received_Daily'] + df['Messages_Sent_Daily']

# %%
df
# Out:
#     User_ID  Age      Gender   Platform  Daily_Usage_Time_min  Posts_Per_Day  \
# 0      1001   23      Female  Instagram                   145              3
# 1      1002   19        Male     TikTok                   210              1
# 2      1003   28      Female   LinkedIn                    45              0
# 3      1004   35        Male   Facebook                    90              2
# 4      1005   21  Non-binary    Twitter                   180             15
# 5      1006   25        Male    YouTube                   240              0
# 6      1007   31      Female  Instagram                    60              1
# 7      1008   22        Male     TikTok                   165              5
# 8      1009   29      Female  Pinterest                    30              0
# 9      1010   40        Male   Facebook                    50              1
# 10     1011   18      Female   Snapchat                   190              8
# 11     1012   26        Male    Twitter                   120             10
# 12     1013   33      Female   LinkedIn                    20              0
# 13     1014   24        Male     Reddit                   150              2
# 14     1015   20      Female     TikTok                   300              4
# 15     1016   27        Male  Instagram                   110              2
# 16     1017   38      Female   Facebook                    40              1
# 17     1018   22  Non-binary    Discord                   200              0
# 18     1019   30        Male    YouTube                   130              0
# 19     1020   19      Female   Snapchat                   175             12
#
#     Likes_Received_Daily  Comments_Received_Daily  Messages_Sent_Daily  \
# 0                    120                       25                   45
# 1                     45                        5                   10
# 2                      5                        2                   15
# 3                     30                       10                   20
# 4                    200                       60                   50
# 5                     10                        1                    0
# 6                     50                        8                   30
# 7                     90                       12                   35
# 8                      2                        0                    5
# 9                     15                        3                   10
# 10                    60                       20                  120
# 11                   150                       45                   25
# 12                     1                        0                    5
# 13                    25                       15                    0
# 14                    80                       30                   40
# 15                    75                       10                   25
# 16                    20                        5                   15
# 17                     5                        2                  300
# 18                    15                        2                    0
# 19                   100                       25                  150
#
#     Scroll_Rate_ppm Addiction_Level Emotional_State_Post_Usage  \
# 0                40            High                    Anxious
# 1                85          Severe                  Depressed
# 2                10             Low                  Motivated
# 3                25        Moderate                    Neutral
# 4                55            High                   Stressed
# 5                10          Severe                      Bored
# 6                20        Moderate                      Happy
# 7                70            High                    Envious
# 8                15             Low                   Inspired
# 9                10             Low                    Neutral
# 10               45            High                     Lonely
# 11               50        Moderate                      Angry
# 12                5             Low                    Neutral
# 13               30        Moderate                    Curious
# 14               95          Severe                    Drained
# 15               35        Moderate                    Anxious
# 16               10             Low                  Connected
# 17               20            High                Overwhelmed
# 18               10        Moderate                    Relaxed
# 19               50            High                   Insecure
#
#     Productivity_Loss_Score  Mental_Health_Index  FOMO_Score  Classe_age  \
# 0                         7                   45           8  Plus Jeune
# 1                         9                   30           9  Plus Jeune
# 2                         2                   80           3      Adulte
# 3                         4                   65           5      Adulte
# 4                         8                   40           7  Plus Jeune
# 5                         9                   35           4  Plus Jeune
# 6                         3                   75           4      Adulte
# 7                         6                   50           8  Plus Jeune
# 8                         1                   85           2      Adulte
# 9                         2                   70           3      Adulte
# 10                        7                   40           9  Plus Jeune
# 11                        5                   55           6  Plus Jeune
# 12                        1                   90           2      Adulte
# 13                        5                   60           5  Plus Jeune
# 14                       10                   25          10  Plus Jeune
# 15                        4                   60           6      Adulte
# 16                        2                   80           3      Adulte
# 17                        8                   45           7  Plus Jeune
# 18                        4                   70           4      Adulte
# 19                        8                   35           9  Plus Jeune
#
#     Interactions
# 0            193
# 1             61
# 2             22
# 3             62
# 4            325
# 5             11
# 6             89
# 7            142
# 8              7
# 9             29
# 10           208
# 11           230
# 12             6
# 13            42
# 14           154
# 15           112
# 16            41
# 17           307
# 18            17
# 19           287

# %%
df['Interactions'].std()
# Out:
# np.float64(107.08573790733243)

# %%
plt.hist(df['Interactions'], bins = 3)
plt.title('Les Interactions')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df[(df['Interactions'] > 212.66) & (df['Interactions'] < 319)]
# Out:
#     User_ID  Age      Gender  Platform  Daily_Usage_Time_min  Posts_Per_Day  \
# 11     1012   26        Male   Twitter                   120             10
# 17     1018   22  Non-binary   Discord                   200              0
# 19     1020   19      Female  Snapchat                   175             12
#
#     Likes_Received_Daily  Comments_Received_Daily  Messages_Sent_Daily  \
# 11                   150                       45                   25
# 17                     5                        2                  300
# 19                   100                       25                  150
#
#     Scroll_Rate_ppm Addiction_Level Emotional_State_Post_Usage  \
# 11               50        Moderate                      Angry
# 17               20            High                Overwhelmed
# 19               50            High                   Insecure
#
#     Productivity_Loss_Score  Mental_Health_Index  FOMO_Score  Classe_age  \
# 11                        5                   55           6  Plus Jeune
# 17                        8                   45           7  Plus Jeune
# 19                        8                   35           9  Plus Jeune
#
#     Interactions
# 11           230
# 17           307
# 19           287

# %%
i
# Out:
#     User_ID  Age  Gender   Platform  Daily_Usage_Time_min  Posts_Per_Day  \
# 1      1002   19    Male     TikTok                   210              1
# 2      1003   28  Female   LinkedIn                    45              0
# 3      1004   35    Male   Facebook                    90              2
# 5      1006   25    Male    YouTube                   240              0
# 6      1007   31  Female  Instagram                    60              1
# 8      1009   29  Female  Pinterest                    30              0
# 9      1010   40    Male   Facebook                    50              1
# 13     1014   24    Male     Reddit                   150              2
# 16     1017   38  Female   Facebook                    40              1
# 18     1019   30    Male    YouTube                   130              0
#
#     Likes_Received_Daily  Comments_Received_Daily  Messages_Sent_Daily  \
# 1                     45                        5                   10
# 2                      5                        2                   15
# 3                     30                       10                   20
# 5                     10                        1                    0
# 6                     50                        8                   30
# 8                      2                        0                    5
# 9                     15                        3                   10
# 13                    25                       15                    0
# 16                    20                        5                   15
# 18                    15                        2                    0
#
#     Scroll_Rate_ppm Addiction_Level Emotional_State_Post_Usage  \
# 1                85          Severe                  Depressed
# 2                10             Low                  Motivated
# 3                25        Moderate                    Neutral
# 5                10          Severe                      Bored
# 6                20        Moderate                      Happy
# 8                15             Low                   Inspired
# 9                10             Low                    Neutral
# 13               30        Moderate                    Curious
# 16               10             Low                  Connected
# 18               10        Moderate                    Relaxed
#
#     Productivity_Loss_Score  Mental_Health_Index  FOMO_Score  Classe_age  \
# 1                         9                   30           9  Plus Jeune
# 2                         2                   80           3      Adulte
# 3                         4                   65           5      Adulte
# 5                         9                   35           4  Plus Jeune
# 6                         3                   75           4      Adulte
# 8                         1                   85           2      Adulte
# 9                         2                   70           3      Adulte
# 13                        5                   60           5  Plus Jeune
# 16                        2                   80           3      Adulte
# 18                        4                   70           4      Adulte
#
#     Interactions
# 1             61
# 2             22
# 3             62
# 5             11
# 6             89
# 8              7
# 9             29
# 13            42
# 16            41
# 18            17
