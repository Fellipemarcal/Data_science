# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('social_media_addiction.csv')
##########################################
def cls_age(i):
    if i < 26.5:
        return 'Plus Jeune'
    else:
        return 'Adulte'
#########################################
def intrct (i):
    if i >= 245.25 and i <= 325:
        return 'Très Haute'
    elif i >= 165.50 and i <= 245.25:
        return 'Haute'
    elif i >= 85.75 and i <= 165.50:
        return 'Normal'
    elif i >= 6 and i <= 85.75:
        return 'Baisse'
##########################################
def usage_niveau (i):
    if i >= 230 and i <= 300:
        return 'Très Haute'
    elif i >= 160 and i <= 230:
        return 'Haute'
    elif i >= 90 and i <= 160:
        return 'Normal'
    elif i >= 20 and i <= 90:
        return 'Baisse'
##########################################
def snt_mnt(i):
    if i >= 73.75 and i <= 90 :
        return 'Bonne santé'
    elif i >= 57.50 and i <= 73.75 :
        return 'Santé stable'
    elif i >= 41.25 and i <= 57.50:
        return 'Santé en attention'
    elif i >= 25 and i <= 41.25 :
        return 'Mauvaise Santé'
##########################################
df['Classe_age'] = df['Age'].apply(cls_age)
df['Interactions'] = df['Posts_Per_Day'] + df['Likes_Received_Daily'] + df['Comments_Received_Daily'] + df['Messages_Sent_Daily']
df['Niveau_interaction'] = df['Interactions'].apply(intrct)
df['Niveau_usage'] = df['Daily_Usage_Time_min'].apply(usage_niveau)
df['Niveau_Santé'] = df['Mental_Health_Index'].apply(snt_mnt)

# %%
p_jeune = df[df['Classe_age'] == 'Plus Jeune']
adulte = df[df['Classe_age'] == 'Adulte']

# %%
df.columns
# Out:
# Index(['User_ID', 'Age', 'Gender', 'Platform', 'Daily_Usage_Time_min',
#        'Posts_Per_Day', 'Likes_Received_Daily', 'Comments_Received_Daily',
#        'Messages_Sent_Daily', 'Scroll_Rate_ppm', 'Addiction_Level',
#        'Emotional_State_Post_Usage', 'Productivity_Loss_Score',
#        'Mental_Health_Index', 'FOMO_Score', 'Classe_age', 'Interactions',
#        'Niveau_interaction', 'Niveau_usage', 'Niveau_Santé'],
#       dtype='object')

# %%
#les niveaux d'addiction élevés (high/severe) sont associés à des états émotionnels plus négatifs ou plus intenses (comme anxious, depressed
#overwhelmed, stressed).
#On remarque aussi que ces cas sont plus fréquents chez les plus jeunes
add_lvl = (
    p_jeune
    .groupby(['Emotional_State_Post_Usage','Addiction_Level'])
    .size()
    .sort_values(ascending = False)
)
add_lvl
# Out:
# Emotional_State_Post_Usage  Addiction_Level
# Angry                       Moderate           1
# Anxious                     High               1
# Bored                       Severe             1
# Curious                     Moderate           1
# Depressed                   Severe             1
# Drained                     Severe             1
# Envious                     High               1
# Insecure                    High               1
# Lonely                      High               1
# Overwhelmed                 High               1
# Stressed                    High               1
# dtype: int64

# %%
p_jeune
# Out:
#     User_ID  Age      Gender   Platform  Daily_Usage_Time_min  Posts_Per_Day  \
# 0      1001   23      Female  Instagram                   145              3
# 1      1002   19        Male     TikTok                   210              1
# 4      1005   21  Non-binary    Twitter                   180             15
# 5      1006   25        Male    YouTube                   240              0
# 7      1008   22        Male     TikTok                   165              5
# 10     1011   18      Female   Snapchat                   190              8
# 11     1012   26        Male    Twitter                   120             10
# 13     1014   24        Male     Reddit                   150              2
# 14     1015   20      Female     TikTok                   300              4
# 17     1018   22  Non-binary    Discord                   200              0
# 19     1020   19      Female   Snapchat                   175             12
#
#     Likes_Received_Daily  Comments_Received_Daily  Messages_Sent_Daily  \
# 0                    120                       25                   45
# 1                     45                        5                   10
# 4                    200                       60                   50
# 5                     10                        1                    0
# 7                     90                       12                   35
# 10                    60                       20                  120
# 11                   150                       45                   25
# 13                    25                       15                    0
# 14                    80                       30                   40
# 17                     5                        2                  300
# 19                   100                       25                  150
#
#     Scroll_Rate_ppm Addiction_Level Emotional_State_Post_Usage  \
# 0                40            High                    Anxious
# 1                85          Severe                  Depressed
# 4                55            High                   Stressed
# 5                10          Severe                      Bored
# 7                70            High                    Envious
# 10               45            High                     Lonely
# 11               50        Moderate                      Angry
# 13               30        Moderate                    Curious
# 14               95          Severe                    Drained
# 17               20            High                Overwhelmed
# 19               50            High                   Insecure
#
#     Productivity_Loss_Score  Mental_Health_Index  FOMO_Score  Classe_age  \
# 0                         7                   45           8  Plus Jeune
# 1                         9                   30           9  Plus Jeune
# 4                         8                   40           7  Plus Jeune
# 5                         9                   35           4  Plus Jeune
# 7                         6                   50           8  Plus Jeune
# 10                        7                   40           9  Plus Jeune
# 11                        5                   55           6  Plus Jeune
# 13                        5                   60           5  Plus Jeune
# 14                       10                   25          10  Plus Jeune
# 17                        8                   45           7  Plus Jeune
# 19                        8                   35           9  Plus Jeune
#
#     Interactions Niveau_interaction Niveau_usage        Niveau_Santé
# 0            193              Haute       Normal  Santé en attention
# 1             61             Baisse        Haute      Mauvaise Santé
# 4            325         Très Haute        Haute      Mauvaise Santé
# 5             11             Baisse   Très Haute      Mauvaise Santé
# 7            142             Normal        Haute  Santé en attention
# 10           208              Haute        Haute      Mauvaise Santé
# 11           230              Haute       Normal  Santé en attention
# 13            42             Baisse       Normal        Santé stable
# 14           154             Normal   Très Haute      Mauvaise Santé
# 17           307         Très Haute        Haute  Santé en attention
# 19           287         Très Haute        Haute      Mauvaise Santé

# %%
adulte
# Out:
#     User_ID  Age  Gender   Platform  Daily_Usage_Time_min  Posts_Per_Day  \
# 2      1003   28  Female   LinkedIn                    45              0
# 3      1004   35    Male   Facebook                    90              2
# 6      1007   31  Female  Instagram                    60              1
# 8      1009   29  Female  Pinterest                    30              0
# 9      1010   40    Male   Facebook                    50              1
# 12     1013   33  Female   LinkedIn                    20              0
# 15     1016   27    Male  Instagram                   110              2
# 16     1017   38  Female   Facebook                    40              1
# 18     1019   30    Male    YouTube                   130              0
#
#     Likes_Received_Daily  Comments_Received_Daily  Messages_Sent_Daily  \
# 2                      5                        2                   15
# 3                     30                       10                   20
# 6                     50                        8                   30
# 8                      2                        0                    5
# 9                     15                        3                   10
# 12                     1                        0                    5
# 15                    75                       10                   25
# 16                    20                        5                   15
# 18                    15                        2                    0
#
#     Scroll_Rate_ppm Addiction_Level Emotional_State_Post_Usage  \
# 2                10             Low                  Motivated
# 3                25        Moderate                    Neutral
# 6                20        Moderate                      Happy
# 8                15             Low                   Inspired
# 9                10             Low                    Neutral
# 12                5             Low                    Neutral
# 15               35        Moderate                    Anxious
# 16               10             Low                  Connected
# 18               10        Moderate                    Relaxed
#
#     Productivity_Loss_Score  Mental_Health_Index  FOMO_Score Classe_age  \
# 2                         2                   80           3     Adulte
# 3                         4                   65           5     Adulte
# 6                         3                   75           4     Adulte
# 8                         1                   85           2     Adulte
# 9                         2                   70           3     Adulte
# 12                        1                   90           2     Adulte
# 15                        4                   60           6     Adulte
# 16                        2                   80           3     Adulte
# 18                        4                   70           4     Adulte
#
#     Interactions Niveau_interaction Niveau_usage  Niveau_Santé
# 2             22             Baisse       Baisse   Bonne santé
# 3             62             Baisse       Normal  Santé stable
# 6             89             Normal       Baisse   Bonne santé
# 8              7             Baisse       Baisse   Bonne santé
# 9             29             Baisse       Baisse  Santé stable
# 12             6             Baisse       Baisse   Bonne santé
# 15           112             Normal       Normal  Santé stable
# 16            41             Baisse       Baisse   Bonne santé
# 18            17             Baisse       Normal  Santé stable

# %%
#ici nous faison la même analyse chez les adultes et nous pouvons remarquer qu'il y a une grand réduction des cas élevés
#avec des niveaux d'addictions plus baisses, nous pouvons abserver la presque absence des cas émotionels négatifs
add_lvl_ = (
    adulte
    .groupby(['Emotional_State_Post_Usage','Addiction_Level'])
    .size()
    .sort_values(ascending = False)
)
add_lvl_
# Out:
# Emotional_State_Post_Usage  Addiction_Level
# Neutral                     Low                2
# Anxious                     Moderate           1
# Happy                       Moderate           1
# Connected                   Low                1
# Inspired                    Low                1
# Motivated                   Low                1
# Neutral                     Moderate           1
# Relaxed                     Moderate           1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     20 non-null     int64
#  1   Age                         20 non-null     int64
#  2   Gender                      20 non-null     object
#  3   Platform                    20 non-null     object
#  4   Daily_Usage_Time_min        20 non-null     int64
#  5   Posts_Per_Day               20 non-null     int64
#  6   Likes_Received_Daily        20 non-null     int64
#  7   Comments_Received_Daily     20 non-null     int64
#  8   Messages_Sent_Daily         20 non-null     int64
#  9   Scroll_Rate_ppm             20 non-null     int64
#  10  Addiction_Level             20 non-null     object
#  11  Emotional_State_Post_Usage  20 non-null     object
#  12  Productivity_Loss_Score     20 non-null     int64
#  13  Mental_Health_Index         20 non-null     int64
#  14  FOMO_Score                  20 non-null     int64
#  15  Classe_age                  20 non-null     object
#  16  Interactions                20 non-null     int64
#  17  Niveau_interaction          20 non-null     object
#  18  Niveau_usage                20 non-null     object
#  19  Niveau_Santé                20 non-null     object
# dtypes: int64(12), object(8)
# memory usage: 3.3+ KB

# %%
df
# Out:
#     User_ID  Age      Gender   Platform  Daily_Usage_Time_min  Posts_Per_Day  \
# 0      1001   23      Female  Instagram                   145              3
# 1      1002   19        Male     TikTok                   210              1
# 2      1003   28      Female   LinkedIn                    45              0
# 3      1004   35        Male   Facebook                    90              2
# 4      1005   21  Non-binary    Twitter                   180             15
# 5      1006   25        Male    YouTube                   240              0
# 6      1007   31      Female  Instagram                    60              1
# 7      1008   22        Male     TikTok                   165              5
# 8      1009   29      Female  Pinterest                    30              0
# 9      1010   40        Male   Facebook                    50              1
# 10     1011   18      Female   Snapchat                   190              8
# 11     1012   26        Male    Twitter                   120             10
# 12     1013   33      Female   LinkedIn                    20              0
# 13     1014   24        Male     Reddit                   150              2
# 14     1015   20      Female     TikTok                   300              4
# 15     1016   27        Male  Instagram                   110              2
# 16     1017   38      Female   Facebook                    40              1
# 17     1018   22  Non-binary    Discord                   200              0
# 18     1019   30        Male    YouTube                   130              0
# 19     1020   19      Female   Snapchat                   175             12
#
#     Likes_Received_Daily  Comments_Received_Daily  Messages_Sent_Daily  \
# 0                    120                       25                   45
# 1                     45                        5                   10
# 2                      5                        2                   15
# 3                     30                       10                   20
# 4                    200                       60                   50
# 5                     10                        1                    0
# 6                     50                        8                   30
# 7                     90                       12                   35
# 8                      2                        0                    5
# 9                     15                        3                   10
# 10                    60                       20                  120
# 11                   150                       45                   25
# 12                     1                        0                    5
# 13                    25                       15                    0
# 14                    80                       30                   40
# 15                    75                       10                   25
# 16                    20                        5                   15
# 17                     5                        2                  300
# 18                    15                        2                    0
# 19                   100                       25                  150
#
#     Scroll_Rate_ppm Addiction_Level Emotional_State_Post_Usage  \
# 0                40            High                    Anxious
# 1                85          Severe                  Depressed
# 2                10             Low                  Motivated
# 3                25        Moderate                    Neutral
# 4                55            High                   Stressed
# 5                10          Severe                      Bored
# 6                20        Moderate                      Happy
# 7                70            High                    Envious
# 8                15             Low                   Inspired
# 9                10             Low                    Neutral
# 10               45            High                     Lonely
# 11               50        Moderate                      Angry
# 12                5             Low                    Neutral
# 13               30        Moderate                    Curious
# 14               95          Severe                    Drained
# 15               35        Moderate                    Anxious
# 16               10             Low                  Connected
# 17               20            High                Overwhelmed
# 18               10        Moderate                    Relaxed
# 19               50            High                   Insecure
#
#     Productivity_Loss_Score  Mental_Health_Index  FOMO_Score  Classe_age  \
# 0                         7                   45           8  Plus Jeune
# 1                         9                   30           9  Plus Jeune
# 2                         2                   80           3      Adulte
# 3                         4                   65           5      Adulte
# 4                         8                   40           7  Plus Jeune
# 5                         9                   35           4  Plus Jeune
# 6                         3                   75           4      Adulte
# 7                         6                   50           8  Plus Jeune
# 8                         1                   85           2      Adulte
# 9                         2                   70           3      Adulte
# 10                        7                   40           9  Plus Jeune
# 11                        5                   55           6  Plus Jeune
# 12                        1                   90           2      Adulte
# 13                        5                   60           5  Plus Jeune
# 14                       10                   25          10  Plus Jeune
# 15                        4                   60           6      Adulte
# 16                        2                   80           3      Adulte
# 17                        8                   45           7  Plus Jeune
# 18                        4                   70           4      Adulte
# 19                        8                   35           9  Plus Jeune
#
#     Interactions Niveau_interaction Niveau_usage        Niveau_Santé
# 0            193              Haute       Normal  Santé en attention
# 1             61             Baisse        Haute      Mauvaise Santé
# 2             22             Baisse       Baisse         Bonne santé
# 3             62             Baisse       Normal        Santé stable
# 4            325         Très Haute        Haute      Mauvaise Santé
# 5             11             Baisse   Très Haute      Mauvaise Santé
# 6             89             Normal       Baisse         Bonne santé
# 7            142             Normal        Haute  Santé en attention
# 8              7             Baisse       Baisse         Bonne santé
# 9             29             Baisse       Baisse        Santé stable
# 10           208              Haute        Haute      Mauvaise Santé
# 11           230              Haute       Normal  Santé en attention
# 12             6             Baisse       Baisse         Bonne santé
# 13            42             Baisse       Normal        Santé stable
# 14           154             Normal   Très Haute      Mauvaise Santé
# 15           112             Normal       Normal        Santé stable
# 16            41             Baisse       Baisse         Bonne santé
# 17           307         Très Haute        Haute  Santé en attention
# 18            17             Baisse       Normal        Santé stable
# 19           287         Très Haute        Haute      Mauvaise Santé

# %%
plt.hist(df['Interactions'], bins = 4)
plt.title('Les Interactions')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df[df['Interactions'] > 165]
# Out:
#     User_ID  Age      Gender   Platform  Daily_Usage_Time_min  Posts_Per_Day  \
# 0      1001   23      Female  Instagram                   145              3
# 4      1005   21  Non-binary    Twitter                   180             15
# 10     1011   18      Female   Snapchat                   190              8
# 11     1012   26        Male    Twitter                   120             10
# 17     1018   22  Non-binary    Discord                   200              0
# 19     1020   19      Female   Snapchat                   175             12
#
#     Likes_Received_Daily  Comments_Received_Daily  Messages_Sent_Daily  \
# 0                    120                       25                   45
# 4                    200                       60                   50
# 10                    60                       20                  120
# 11                   150                       45                   25
# 17                     5                        2                  300
# 19                   100                       25                  150
#
#     Scroll_Rate_ppm Addiction_Level Emotional_State_Post_Usage  \
# 0                40            High                    Anxious
# 4                55            High                   Stressed
# 10               45            High                     Lonely
# 11               50        Moderate                      Angry
# 17               20            High                Overwhelmed
# 19               50            High                   Insecure
#
#     Productivity_Loss_Score  Mental_Health_Index  FOMO_Score  Classe_age  \
# 0                         7                   45           8  Plus Jeune
# 4                         8                   40           7  Plus Jeune
# 10                        7                   40           9  Plus Jeune
# 11                        5                   55           6  Plus Jeune
# 17                        8                   45           7  Plus Jeune
# 19                        8                   35           9  Plus Jeune
#
#     Interactions Niveau_interaction Niveau_usage        Niveau_Santé
# 0            193              Haute       Normal  Santé en attention
# 4            325         Très Haute        Haute      Mauvaise Santé
# 10           208              Haute        Haute      Mauvaise Santé
# 11           230              Haute       Normal  Santé en attention
# 17           307         Très Haute        Haute  Santé en attention
# 19           287         Très Haute        Haute      Mauvaise Santé

# %%
df['Daily_Usage_Time_min'].std()
# Out:
# np.float64(77.11065186846074)

# %%
df
# Out:
#     User_ID  Age      Gender   Platform  Daily_Usage_Time_min  Posts_Per_Day  \
# 0      1001   23      Female  Instagram                   145              3
# 1      1002   19        Male     TikTok                   210              1
# 2      1003   28      Female   LinkedIn                    45              0
# 3      1004   35        Male   Facebook                    90              2
# 4      1005   21  Non-binary    Twitter                   180             15
# 5      1006   25        Male    YouTube                   240              0
# 6      1007   31      Female  Instagram                    60              1
# 7      1008   22        Male     TikTok                   165              5
# 8      1009   29      Female  Pinterest                    30              0
# 9      1010   40        Male   Facebook                    50              1
# 10     1011   18      Female   Snapchat                   190              8
# 11     1012   26        Male    Twitter                   120             10
# 12     1013   33      Female   LinkedIn                    20              0
# 13     1014   24        Male     Reddit                   150              2
# 14     1015   20      Female     TikTok                   300              4
# 15     1016   27        Male  Instagram                   110              2
# 16     1017   38      Female   Facebook                    40              1
# 17     1018   22  Non-binary    Discord                   200              0
# 18     1019   30        Male    YouTube                   130              0
# 19     1020   19      Female   Snapchat                   175             12
#
#     Likes_Received_Daily  Comments_Received_Daily  Messages_Sent_Daily  \
# 0                    120                       25                   45
# 1                     45                        5                   10
# 2                      5                        2                   15
# 3                     30                       10                   20
# 4                    200                       60                   50
# 5                     10                        1                    0
# 6                     50                        8                   30
# 7                     90                       12                   35
# 8                      2                        0                    5
# 9                     15                        3                   10
# 10                    60                       20                  120
# 11                   150                       45                   25
# 12                     1                        0                    5
# 13                    25                       15                    0
# 14                    80                       30                   40
# 15                    75                       10                   25
# 16                    20                        5                   15
# 17                     5                        2                  300
# 18                    15                        2                    0
# 19                   100                       25                  150
#
#     Scroll_Rate_ppm Addiction_Level Emotional_State_Post_Usage  \
# 0                40            High                    Anxious
# 1                85          Severe                  Depressed
# 2                10             Low                  Motivated
# 3                25        Moderate                    Neutral
# 4                55            High                   Stressed
# 5                10          Severe                      Bored
# 6                20        Moderate                      Happy
# 7                70            High                    Envious
# 8                15             Low                   Inspired
# 9                10             Low                    Neutral
# 10               45            High                     Lonely
# 11               50        Moderate                      Angry
# 12                5             Low                    Neutral
# 13               30        Moderate                    Curious
# 14               95          Severe                    Drained
# 15               35        Moderate                    Anxious
# 16               10             Low                  Connected
# 17               20            High                Overwhelmed
# 18               10        Moderate                    Relaxed
# 19               50            High                   Insecure
#
#     Productivity_Loss_Score  Mental_Health_Index  FOMO_Score  Classe_age  \
# 0                         7                   45           8  Plus Jeune
# 1                         9                   30           9  Plus Jeune
# 2                         2                   80           3      Adulte
# 3                         4                   65           5      Adulte
# 4                         8                   40           7  Plus Jeune
# 5                         9                   35           4  Plus Jeune
# 6                         3                   75           4      Adulte
# 7                         6                   50           8  Plus Jeune
# 8                         1                   85           2      Adulte
# 9                         2                   70           3      Adulte
# 10                        7                   40           9  Plus Jeune
# 11                        5                   55           6  Plus Jeune
# 12                        1                   90           2      Adulte
# 13                        5                   60           5  Plus Jeune
# 14                       10                   25          10  Plus Jeune
# 15                        4                   60           6      Adulte
# 16                        2                   80           3      Adulte
# 17                        8                   45           7  Plus Jeune
# 18                        4                   70           4      Adulte
# 19                        8                   35           9  Plus Jeune
#
#     Interactions Niveau_interaction Niveau_usage        Niveau_Santé
# 0            193              Haute       Normal  Santé en attention
# 1             61             Baisse        Haute      Mauvaise Santé
# 2             22             Baisse       Baisse         Bonne santé
# 3             62             Baisse       Normal        Santé stable
# 4            325         Très Haute        Haute      Mauvaise Santé
# 5             11             Baisse   Très Haute      Mauvaise Santé
# 6             89             Normal       Baisse         Bonne santé
# 7            142             Normal        Haute  Santé en attention
# 8              7             Baisse       Baisse         Bonne santé
# 9             29             Baisse       Baisse        Santé stable
# 10           208              Haute        Haute      Mauvaise Santé
# 11           230              Haute       Normal  Santé en attention
# 12             6             Baisse       Baisse         Bonne santé
# 13            42             Baisse       Normal        Santé stable
# 14           154             Normal   Très Haute      Mauvaise Santé
# 15           112             Normal       Normal        Santé stable
# 16            41             Baisse       Baisse         Bonne santé
# 17           307         Très Haute        Haute  Santé en attention
# 18            17             Baisse       Normal        Santé stable
# 19           287         Très Haute        Haute      Mauvaise Santé

# %%
df['Interactions'].corr(df['Daily_Usage_Time_min'])
# Out:
# np.float64(0.482865331582041)

# %%
a = df['Daily_Usage_Time_min'].sort_values(ascending = False).head(5)

# %%
df[df['Daily_Usage_Time_min'].isin(a)]
# Out:
#     User_ID  Age      Gender  Platform  Daily_Usage_Time_min  Posts_Per_Day  \
# 1      1002   19        Male    TikTok                   210              1
# 5      1006   25        Male   YouTube                   240              0
# 10     1011   18      Female  Snapchat                   190              8
# 14     1015   20      Female    TikTok                   300              4
# 17     1018   22  Non-binary   Discord                   200              0
#
#     Likes_Received_Daily  Comments_Received_Daily  Messages_Sent_Daily  \
# 1                     45                        5                   10
# 5                     10                        1                    0
# 10                    60                       20                  120
# 14                    80                       30                   40
# 17                     5                        2                  300
#
#     Scroll_Rate_ppm Addiction_Level Emotional_State_Post_Usage  \
# 1                85          Severe                  Depressed
# 5                10          Severe                      Bored
# 10               45            High                     Lonely
# 14               95          Severe                    Drained
# 17               20            High                Overwhelmed
#
#     Productivity_Loss_Score  Mental_Health_Index  FOMO_Score  Classe_age  \
# 1                         9                   30           9  Plus Jeune
# 5                         9                   35           4  Plus Jeune
# 10                        7                   40           9  Plus Jeune
# 14                       10                   25          10  Plus Jeune
# 17                        8                   45           7  Plus Jeune
#
#     Interactions Niveau_interaction Niveau_usage        Niveau_Santé
# 1             61             Baisse        Haute      Mauvaise Santé
# 5             11             Baisse   Très Haute      Mauvaise Santé
# 10           208              Haute        Haute      Mauvaise Santé
# 14           154             Normal   Très Haute      Mauvaise Santé
# 17           307         Très Haute        Haute  Santé en attention

# %%
Addiction_Platform = (
    df
    .groupby(['Addiction_Level','Platform'])
    .size()
    .sort_values(ascending = False)
)
Addiction_Platform
# Out:
# Addiction_Level  Platform
# High             Snapchat     2
# Low              Facebook     2
#                  LinkedIn     2
# Severe           TikTok       2
# Moderate         Instagram    2
# High             Instagram    1
#                  Discord      1
#                  TikTok       1
#                  Twitter      1
# Moderate         Facebook     1
# Low              Pinterest    1
# Moderate         Reddit       1
#                  Twitter      1
#                  YouTube      1
# Severe           YouTube      1
# dtype: int64

# %%
Addiction_Platform
# Out:
# Addiction_Level  Platform
# High             Snapchat     2
# Low              Facebook     2
#                  LinkedIn     2
# Severe           TikTok       2
# Moderate         Instagram    2
# High             Instagram    1
#                  Discord      1
#                  TikTok       1
#                  Twitter      1
# Moderate         Facebook     1
# Low              Pinterest    1
# Moderate         Reddit       1
#                  Twitter      1
#                  YouTube      1
# Severe           YouTube      1
# dtype: int64

# %%
lvl = df['Addiction_Level'].unique()

# %%
lvl
# Out:
# array(['High', 'Severe', 'Low', 'Moderate'], dtype=object)

# %%
df_add  = []
for i in lvl:
    a = Addiction_Platform[i]
    df_add.append(a)
    
df_add_ = pd.DataFrame(df_add)
df_add_ = df_add_.fillna(0)
df_add_ = df_add_.T

# %%
df_add_.columns =lvl.tolist()

# %%
df_add_
# Out:
#            High  Severe  Low  Moderate
# Platform
# Snapchat    2.0     0.0  0.0       0.0
# Instagram   1.0     0.0  0.0       2.0
# Discord     1.0     0.0  0.0       0.0
# TikTok      1.0     2.0  0.0       0.0
# Twitter     1.0     0.0  0.0       1.0
# YouTube     0.0     1.0  0.0       1.0
# Facebook    0.0     0.0  2.0       1.0
# LinkedIn    0.0     0.0  2.0       0.0
# Pinterest   0.0     0.0  1.0       0.0
# Reddit      0.0     0.0  0.0       1.0

# %%
#Ce graphique nous montre que TikTok contient légèrement la plupart des cas d'addictions plus élevés
plt.figure(figsize=(12,6))
sns.heatmap(df_add_, annot=True, fmt=".0f")
plt.title("Niveau d'addiction par Plateforme")
plt.show()

# %%
df['Mental_Health_Index'].mean()
# Out:
# np.float64(56.75)

# %%
plt.hist(df['Mental_Health_Index'], bins = 4)
plt.title('Santé Mentale')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df
# Out:
#     User_ID  Age      Gender   Platform  Daily_Usage_Time_min  Posts_Per_Day  \
# 0      1001   23      Female  Instagram                   145              3
# 1      1002   19        Male     TikTok                   210              1
# 2      1003   28      Female   LinkedIn                    45              0
# 3      1004   35        Male   Facebook                    90              2
# 4      1005   21  Non-binary    Twitter                   180             15
# 5      1006   25        Male    YouTube                   240              0
# 6      1007   31      Female  Instagram                    60              1
# 7      1008   22        Male     TikTok                   165              5
# 8      1009   29      Female  Pinterest                    30              0
# 9      1010   40        Male   Facebook                    50              1
# 10     1011   18      Female   Snapchat                   190              8
# 11     1012   26        Male    Twitter                   120             10
# 12     1013   33      Female   LinkedIn                    20              0
# 13     1014   24        Male     Reddit                   150              2
# 14     1015   20      Female     TikTok                   300              4
# 15     1016   27        Male  Instagram                   110              2
# 16     1017   38      Female   Facebook                    40              1
# 17     1018   22  Non-binary    Discord                   200              0
# 18     1019   30        Male    YouTube                   130              0
# 19     1020   19      Female   Snapchat                   175             12
#
#     Likes_Received_Daily  Comments_Received_Daily  Messages_Sent_Daily  \
# 0                    120                       25                   45
# 1                     45                        5                   10
# 2                      5                        2                   15
# 3                     30                       10                   20
# 4                    200                       60                   50
# 5                     10                        1                    0
# 6                     50                        8                   30
# 7                     90                       12                   35
# 8                      2                        0                    5
# 9                     15                        3                   10
# 10                    60                       20                  120
# 11                   150                       45                   25
# 12                     1                        0                    5
# 13                    25                       15                    0
# 14                    80                       30                   40
# 15                    75                       10                   25
# 16                    20                        5                   15
# 17                     5                        2                  300
# 18                    15                        2                    0
# 19                   100                       25                  150
#
#     Scroll_Rate_ppm Addiction_Level Emotional_State_Post_Usage  \
# 0                40            High                    Anxious
# 1                85          Severe                  Depressed
# 2                10             Low                  Motivated
# 3                25        Moderate                    Neutral
# 4                55            High                   Stressed
# 5                10          Severe                      Bored
# 6                20        Moderate                      Happy
# 7                70            High                    Envious
# 8                15             Low                   Inspired
# 9                10             Low                    Neutral
# 10               45            High                     Lonely
# 11               50        Moderate                      Angry
# 12                5             Low                    Neutral
# 13               30        Moderate                    Curious
# 14               95          Severe                    Drained
# 15               35        Moderate                    Anxious
# 16               10             Low                  Connected
# 17               20            High                Overwhelmed
# 18               10        Moderate                    Relaxed
# 19               50            High                   Insecure
#
#     Productivity_Loss_Score  Mental_Health_Index  FOMO_Score  Classe_age  \
# 0                         7                   45           8  Plus Jeune
# 1                         9                   30           9  Plus Jeune
# 2                         2                   80           3      Adulte
# 3                         4                   65           5      Adulte
# 4                         8                   40           7  Plus Jeune
# 5                         9                   35           4  Plus Jeune
# 6                         3                   75           4      Adulte
# 7                         6                   50           8  Plus Jeune
# 8                         1                   85           2      Adulte
# 9                         2                   70           3      Adulte
# 10                        7                   40           9  Plus Jeune
# 11                        5                   55           6  Plus Jeune
# 12                        1                   90           2      Adulte
# 13                        5                   60           5  Plus Jeune
# 14                       10                   25          10  Plus Jeune
# 15                        4                   60           6      Adulte
# 16                        2                   80           3      Adulte
# 17                        8                   45           7  Plus Jeune
# 18                        4                   70           4      Adulte
# 19                        8                   35           9  Plus Jeune
#
#     Interactions Niveau_interaction Niveau_usage        Niveau_Santé
# 0            193              Haute       Normal  Santé en attention
# 1             61             Baisse        Haute      Mauvaise Santé
# 2             22             Baisse       Baisse         Bonne santé
# 3             62             Baisse       Normal        Santé stable
# 4            325         Très Haute        Haute      Mauvaise Santé
# 5             11             Baisse   Très Haute      Mauvaise Santé
# 6             89             Normal       Baisse         Bonne santé
# 7            142             Normal        Haute  Santé en attention
# 8              7             Baisse       Baisse         Bonne santé
# 9             29             Baisse       Baisse        Santé stable
# 10           208              Haute        Haute      Mauvaise Santé
# 11           230              Haute       Normal  Santé en attention
# 12             6             Baisse       Baisse         Bonne santé
# 13            42             Baisse       Normal        Santé stable
# 14           154             Normal   Très Haute      Mauvaise Santé
# 15           112             Normal       Normal        Santé stable
# 16            41             Baisse       Baisse         Bonne santé
# 17           307         Très Haute        Haute  Santé en attention
# 18            17             Baisse       Normal        Santé stable
# 19           287         Très Haute        Haute      Mauvaise Santé

# %%
snt = (
    df
    .groupby(['Niveau_Santé','Niveau_usage'])
    .size()
    .sort_values(ascending = False)
)
snt
# Out:
# Niveau_Santé        Niveau_usage
# Bonne santé         Baisse          5
# Mauvaise Santé      Haute           4
# Santé stable        Normal          4
# Mauvaise Santé      Très Haute      2
# Santé en attention  Haute           2
#                     Normal          2
# Santé stable        Baisse          1
# dtype: int64
